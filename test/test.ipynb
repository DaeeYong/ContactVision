# %%
import numpy as np

# %%
raw = np.load('/Users/ivory/Documents/github/ContactVision/data/sample/2d_joint_npy/raw/4.npy')
processed = np.load('/Users/ivory/Documents/github/ContactVision/data/sample/2d_joint_npy/processed/4.npy')

# %%
print(raw.shape)
print(processed.shape)
# Out:
# (167, 25, 3)
# (167, 13, 3)
